# %%
import cv2
import pandas as pd
import os
import numpy as np

# --- Cấu hình (ĐÃ CẬP NHẬT) ---
BASE_VIDEO_PATH = "DATA/RawVideo"  # <-- ĐÃ THAY ĐỔI
CLIP_OUTPUT_PATH = "DATA/data_clips/test" # Thư mục lưu clip test đã cắt
ANNOTATION_FILE = "DATA/cleaned_annotations.csv" # File CSV đã làm sạch từ bước trước

# %%
# --- (MỚI) Xây dựng bộ đệm (cache) tìm kiếm file ---
# Quét toàn bộ thư mục BASE_VIDEO_PATH và các thư mục con
print(f"Đang quét thư mục video gốc: {BASE_VIDEO_PATH}...")
video_path_cache = {} # Dict để tra cứu: "video_name.mp4" -> "full/path/to/video_name.mp4"

for root, dirs, files in os.walk(BASE_VIDEO_PATH):
    for file in files:
        if file.endswith(('.mp4', '.avi', '.mkv', '.x264')): # Hỗ trợ các định dạng video
            video_path_cache[file] = os.path.join(root, file)

print(f"Đã tìm thấy {len(video_path_cache)} video trong {BASE_VIDEO_PATH}.")
# ----------------------------------------------------
# Out:
# Đang quét thư mục video gốc: DATA/RawVideo...
# Đã tìm thấy 1900 video trong DATA/RawVideo.

# %%
# Đảm bảo các thư mục đầu ra tồn tại
if not os.path.exists(CLIP_OUTPUT_PATH):
    os.makedirs(CLIP_OUTPUT_PATH)

# --- Hàm cắt video (ĐÃ CẬP NHẬT) ---
def trim_video_clip(source_video_name, output_clip_name, label, start_frame, end_frame):
    """
    Cắt một video clip từ frame_start đến frame_end và lưu nó.
    """
    
    # (CẬP NHẬT) Tìm đường dẫn video từ cache
    if source_video_name not in video_path_cache:
        print(f"CẢNH BÁO: Không tìm thấy video '{source_video_name}' trong {BASE_VIDEO_PATH} hoặc các thư mục con.")
        return
    
    source_video_full_path = video_path_cache[source_video_name] # <-- Lấy từ cache
    
    # Tạo thư mục cho nhãn nếu chưa có (ví dụ: data_clips/test/Arson)
    label_dir = os.path.join(CLIP_OUTPUT_PATH, label)
    if not os.path.exists(label_dir):
        os.makedirs(label_dir)
        
    output_clip_full_path = os.path.join(label_dir, output_clip_name)

    # 1. Mở video gốc
    cap = cv2.VideoCapture(source_video_full_path)
    if not cap.isOpened():
        print(f"LỖI: Không thể mở video gốc: {source_video_full_path}")
        return

    # Lấy thông tin video (FPS, kích thước frame)
    fps = cap.get(cv2.CAP_PROP_FPS)
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    
    # 2. Tạo đối tượng VideoWriter để lưu clip mới
    fourcc = cv2.VideoWriter_fourcc(*'mp4v') # Codec
    writer = cv2.VideoWriter(output_clip_full_path, fourcc, fps, (frame_width, frame_height))

    print(f"Đang xử lý: {output_clip_full_path}...")

    # 3. Đặt vị trí frame bắt đầu
    cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
    
    current_frame = start_frame
    
    # 4. Lặp và ghi đè các frame
    while current_frame <= end_frame:
        ret, frame = cap.read()
        if not ret:
            break
        writer.write(frame)
        current_frame += 1

    # 5. Giải phóng tài nguyên
    cap.release()
    writer.release()

# %%
# --- Hàm xử lý cho video 'Normal' (ĐÃ CẬP NHẬT) ---
def copy_normal_video(source_video_name, label):
    """
    Cắt video Normal thành các đoạn 5 giây.
    """
    
    # (CẬP NHẬT) Tìm đường dẫn video từ cache
    if source_video_name not in video_path_cache:
        print(f"CẢNH BÁO: Không tìm thấy video '{source_video_name}' trong {BASE_VIDEO_PATH} hoặc các thư mục con.")
        return
            
    source_video_full_path = video_path_cache[source_video_name] # <-- Lấy từ cache
    
    label_dir = os.path.join(CLIP_OUTPUT_PATH, label)
    if not os.path.exists(label_dir):
        os.makedirs(label_dir)

    cap = cv2.VideoCapture(source_video_full_path)
    if not cap.isOpened():
        print(f"LỖI: Không thể mở video gốc: {source_video_full_path}")
        return

    fps = cap.get(cv2.CAP_PROP_FPS)
    if fps == 0: fps = 30 # Giá trị mặc định nếu không đọc được
        
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    clip_duration_frames = int(fps * 5) # Cắt thành các clip 5 giây
    
    clip_count = 0
    for start_frame in range(0, total_frames, clip_duration_frames):
        end_frame = min(start_frame + clip_duration_frames - 1, total_frames - 1)
        
        # Bỏ qua nếu clip quá ngắn
        if (end_frame - start_frame) < (fps * 1): # Bỏ qua clip dưới 1 giây
            continue
            
        clip_count += 1
        output_clip_name = f"{source_video_name.split('.')[0]}_clip{clip_count}.mp4"
        
        # Tái sử dụng hàm trim (bây giờ đã an toàn vì nó tra cứu cache)
        trim_video_clip(source_video_name, output_clip_name, label, start_frame, end_frame)

# %%
# --- Vòng lặp chính (Không thay đổi) ---
print("Bắt đầu quá trình chuẩn bị dữ liệu Test...")
try:
    df = pd.read_csv(ANNOTATION_FILE)
except FileNotFoundError:
    print(f"LỖI: Không tìm thấy file '{ANNOTATION_FILE}'. Bạn đã chạy script để tạo file này chưa?")
    exit()

for index, row in df.iterrows():
    if row['start_frame'] == -1 and row['label'] == 'Normal':
        # Xử lý video Normal
        copy_normal_video(row['source_video'], row['label'])
    elif row['start_frame'] != -1:
        # Xử lý video bất thường
        trim_video_clip(
            row['source_video'],
            row['output_name'],
            row['label'],
            int(row['start_frame']),
            int(row['end_frame'])
        )

print(f"Hoàn thành chuẩn bị dữ liệu Test! Dữ liệu đã được lưu tại: {CLIP_OUTPUT_PATH}")
# Out:
# Bắt đầu quá trình chuẩn bị dữ liệu Test...
# Đang xử lý: DATA/data_clips/test\Abuse\Abuse028_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Abuse\Abuse030_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Arrest\Arrest001_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Arrest\Arrest007_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Arrest\Arrest024_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Arrest\Arrest030_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Arrest\Arrest039_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Arson\Arson007_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Arson\Arson009_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Arson\Arson010_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Arson\Arson011_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Arson\Arson011_x264_clip2.mp4...
# Đang xử lý: DATA/data_clips/test\Arson\Arson016_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Arson\Arson018_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Arson\Arson022_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Arson\Arson035_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Arson\Arson041_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Assault\Assault006_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Assault\Assault010_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Assault\Assault010_x264_clip2.mp4...
# Đang xử lý: DATA/data_clips/test\Assault\Assault011_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Burglary\Burglary005_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Burglary\Burglary017_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Burglary\Burglary018_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Burglary\Burglary021_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Burglary\Burglary021_x264_clip2.mp4...
# Đang xử lý: DATA/data_clips/test\Burglary\Burglary024_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Burglary\Burglary032_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Burglary\Burglary033_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Burglary\Burglary035_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Burglary\Burglary037_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Burglary\Burglary037_x264_clip2.mp4...
# Đang xử lý: DATA/data_clips/test\Burglary\Burglary061_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Burglary\Burglary076_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Burglary\Burglary079_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\
mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip18.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip19.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip20.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip21.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip22.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip23.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip24.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip25.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip26.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip27.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip28.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip29.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip30.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip31.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip32.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip33.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip34.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip35.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip36.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip37.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip38.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip39.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip40.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip41.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip42.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip43.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip44.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip45.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip46.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_224_x264_clip47.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip2.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip3.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip4.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip5.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip6.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip7.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip8.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip9.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip10.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip11.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip12.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip13.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip14.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip15.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip16.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip17.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip18.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip19.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip20.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip21.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip22.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip23.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip24.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip25.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip26.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip27.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip28.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip29.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip30.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip31.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip32.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip33.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_246_x264_clip34.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip2.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip3.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip4.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip5.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip6.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip7.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip8.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip9.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip10.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip11.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip12.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip13.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip14.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip15.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip16.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip17.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip18.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip19.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip20.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip21.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip22.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip23.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip24.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip25.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip26.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip27.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip28.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip29.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip30.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip31.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_247_x264_clip32.mp4...
# ...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip196.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip197.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip198.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip199.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip200.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip201.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip202.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip203.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip204.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip205.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip206.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip207.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip208.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip209.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip210.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip211.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip212.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip213.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip214.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip215.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip216.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip217.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip218.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip219.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip220.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip221.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip222.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip223.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip224.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip225.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip226.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip227.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip228.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip229.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip230.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip231.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip232.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip233.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip234.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip235.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip236.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip237.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip238.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip239.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_940_x264_clip240.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_941_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_941_x264_clip2.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_941_x264_clip3.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_941_x264_clip4.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_941_x264_clip5.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_941_x264_clip6.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_941_x264_clip7.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_941_x264_clip8.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_941_x264_clip9.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_941_x264_clip10.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_941_x264_clip11.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_941_x264_clip12.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_941_x264_clip13.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_941_x264_clip14.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_943_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_943_x264_clip2.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_943_x264_clip3.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_943_x264_clip4.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_943_x264_clip5.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_943_x264_clip6.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_943_x264_clip7.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip2.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip3.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip4.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip5.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip6.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip7.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip8.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip9.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip10.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip11.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip12.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip13.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip14.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip15.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip16.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip17.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip18.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip19.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip20.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip21.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip22.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip23.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip24.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip25.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip26.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip27.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip28.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip29.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip30.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip31.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip32.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip33.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip34.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip35.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip36.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip37.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip38.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip39.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip40.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip41.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip42.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip43.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip44.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip45.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip46.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip47.mp4...
# Đang xử lý: DATA/data_clips/test\Normal\Normal_Videos_944_x264_clip48.mp4...
# Đang xử lý: DATA/data_clips/test\RoadAccidents\RoadAccidents001_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\RoadAccidents\RoadAccidents002_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\RoadAccidents\RoadAccidents004_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\RoadAccidents\RoadAccidents009_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\RoadAccidents\RoadAccidents010_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\RoadAccidents\RoadAccidents011_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\RoadAccidents\RoadAccidents012_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\RoadAccidents\RoadAccidents016_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\RoadAccidents\RoadAccidents017_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\RoadAccidents\RoadAccidents019_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\RoadAccidents\RoadAccidents020_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\RoadAccidents\RoadAccidents021_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\RoadAccidents\RoadAccidents022_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\RoadAccidents\RoadAccidents121_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\RoadAccidents\RoadAccidents122_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\RoadAccidents\RoadAccidents123_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\RoadAccidents\RoadAccidents124_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\RoadAccidents\RoadAccidents125_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\RoadAccidents\RoadAccidents127_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\RoadAccidents\RoadAccidents128_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\RoadAccidents\RoadAccidents131_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\RoadAccidents\RoadAccidents132_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\RoadAccidents\RoadAccidents133_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Robbery\Robbery048_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Robbery\Robbery050_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Robbery\Robbery102_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Robbery\Robbery106_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Robbery\Robbery137_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shooting\Shooting002_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shooting\Shooting004_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shooting\Shooting007_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shooting\Shooting008_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shooting\Shooting010_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shooting\Shooting011_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shooting\Shooting013_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shooting\Shooting015_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shooting\Shooting018_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shooting\Shooting019_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shooting\Shooting021_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shooting\Shooting022_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shooting\Shooting024_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shooting\Shooting026_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shooting\Shooting028_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shooting\Shooting032_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shooting\Shooting033_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shooting\Shooting034_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shooting\Shooting037_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shooting\Shooting043_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shooting\Shooting046_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shooting\Shooting046_x264_clip2.mp4...
# Đang xử lý: DATA/data_clips/test\Shooting\Shooting047_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shooting\Shooting047_x264_clip2.mp4...
# Đang xử lý: DATA/data_clips/test\Shooting\Shooting048_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shoplifting\Shoplifting001_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shoplifting\Shoplifting004_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shoplifting\Shoplifting005_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shoplifting\Shoplifting007_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shoplifting\Shoplifting007_x264_clip2.mp4...
# Đang xử lý: DATA/data_clips/test\Shoplifting\Shoplifting010_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shoplifting\Shoplifting010_x264_clip2.mp4...
# Đang xử lý: DATA/data_clips/test\Shoplifting\Shoplifting015_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shoplifting\Shoplifting016_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shoplifting\Shoplifting017_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shoplifting\Shoplifting020_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shoplifting\Shoplifting021_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shoplifting\Shoplifting022_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shoplifting\Shoplifting022_x264_clip2.mp4...
# Đang xử lý: DATA/data_clips/test\Shoplifting\Shoplifting027_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shoplifting\Shoplifting027_x264_clip2.mp4...
# Đang xử lý: DATA/data_clips/test\Shoplifting\Shoplifting028_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shoplifting\Shoplifting029_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shoplifting\Shoplifting031_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shoplifting\Shoplifting033_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shoplifting\Shoplifting034_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shoplifting\Shoplifting037_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shoplifting\Shoplifting039_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shoplifting\Shoplifting044_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Shoplifting\Shoplifting049_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Stealing\Stealing019_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Stealing\Stealing019_x264_clip2.mp4...
# Đang xử lý: DATA/data_clips/test\Stealing\Stealing036_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Stealing\Stealing058_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Stealing\Stealing062_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Stealing\Stealing079_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Stealing\Stealing079_x264_clip2.mp4...
# Đang xử lý: DATA/data_clips/test\Vandalism\Vandalism007_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Vandalism\Vandalism015_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Vandalism\Vandalism017_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Vandalism\Vandalism017_x264_clip2.mp4...
# Đang xử lý: DATA/data_clips/test\Vandalism\Vandalism028_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Vandalism\Vandalism028_x264_clip2.mp4...
# Đang xử lý: DATA/data_clips/test\Vandalism\Vandalism036_x264_clip1.mp4...
# Đang xử lý: DATA/data_clips/test\Vandalism\Vandalism036_x264_clip2.mp4...
# Hoàn thành chuẩn bị dữ liệu Test! Dữ liệu đã được lưu tại: DATA/data_clips/test
