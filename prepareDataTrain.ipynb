# %%
import cv2
import pandas as pd
import os
import shutil

# --- Cấu hình ---
BASE_VIDEO_PATH = "DATA/RawVideo" # Thư mục video gốc
CLIP_OUTPUT_PATH = "DATA/data_clips/train" # Thư mục lưu clip train
TRAIN_SPLIT_FILE = "train_data.txt" # File split

CLIP_DURATION_SEC = 5 # Độ dài mỗi clip (giây)
SLIDE_SEC = 2         # Trượt 2 giây (giảm chồng lấn, tăng tốc độ)

# --- (MỚI) Xây dựng bộ đệm (cache) tìm kiếm file ---
print(f"Đang quét thư mục video gốc: {BASE_VIDEO_PATH}...")
video_path_cache = {}
for root, dirs, files in os.walk(BASE_VIDEO_PATH):
    for file in files:
        if file.endswith(('.mp4', '.avi', '.x264')):
            video_path_cache[file] = os.path.join(root, file)
print(f"Đã tìm thấy {len(video_path_cache)} video.")
# ----------------------------------------------------
# Out:
# Đang quét thư mục video gốc: DATA/RawVideo...
# Đã tìm thấy 1900 video.

# %%
# --- Hàm cắt video (cửa sổ trượt) ---
# (Hàm này giữ nguyên, không thay đổi)
def trim_video_sliding_window(source_video_name, label):
    
    if source_video_name not in video_path_cache:
        print(f"CẢNH BÁO (Train): Không tìm thấy video '{source_video_name}'. Bỏ qua.")
        return 0

    source_video_full_path = video_path_cache[source_video_name]
    
    label_dir = os.path.join(CLIP_OUTPUT_PATH, label)
    if not os.path.exists(label_dir):
        os.makedirs(label_dir)

    cap = cv2.VideoCapture(source_video_full_path)
    if not cap.isOpened():
        print(f"LỖI: Không thể mở video gốc: {source_video_full_path}")
        return 0

    fps = cap.get(cv2.CAP_PROP_FPS)
    if fps == 0: fps = 30
        
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    
    clip_duration_frames = int(fps * CLIP_DURATION_SEC)
    slide_frames = int(fps * SLIDE_SEC)
    
    clip_count = 0
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')

    for start_frame in range(0, total_frames - clip_duration_frames + 1, slide_frames):
        end_frame = start_frame + clip_duration_frames
        clip_count += 1
        output_clip_name = f"{source_video_name.split('.')[0]}_clip{clip_count}.mp4"
        output_clip_full_path = os.path.join(label_dir, output_clip_name)

        # Mở writer
        writer = cv2.VideoWriter(output_clip_full_path, fourcc, fps, (frame_width, frame_height))
        
        # Đặt vị trí frame
        cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
        
        # Ghi N frame
        for i in range(clip_duration_frames):
            ret, frame = cap.read()
            if not ret: break
            writer.write(frame)
        
        writer.release()

    cap.release()
    # Tắt log này để đỡ nhiễu, chỉ bật khi cần debug
    print(f"  Đã cắt video '{source_video_name}' thành {clip_count} clips.")
    return clip_count

# %%
# --- Vòng lặp chính (ĐÃ CẬP NHẬT) ---
print("Bắt đầu chuẩn bị dữ liệu Train (Sliding Window)...")

# Đảm bảo thư mục gốc tồn tại
if not os.path.exists(CLIP_OUTPUT_PATH):
    os.makedirs(CLIP_OUTPUT_PATH)

try:
    with open(TRAIN_SPLIT_FILE, 'r') as f:
        train_videos_list = f.readlines()
except FileNotFoundError:
    print(f"LỖI: Không tìm thấy file split huấn luyện '{TRAIN_SPLIT_FILE}'.")
    exit()

total_clips_generated_this_run = 0
total_videos_processed = 0
total_videos_skipped = 0

print(f"Tổng số video cần kiểm tra: {len(train_videos_list)}")

for line in train_videos_list:
    line = line.strip()
    if not line: continue
    
    try:
        # Giả định định dạng là "Label/VideoName.mp4"
        label, video_name = line.split('/')
    except ValueError:
        print(f"Bỏ qua dòng không đúng định dạng: {line}")
        continue
    
    # Đặc biệt: Xử lý cho "Normal" nếu nó nằm trong thư mục con khác
    if label == "Normal_Videos_event":
        label = "Normal"
        # (Tùy chỉnh nếu cần)
        
    # --- (THÊM MỚI) KIỂM TRA XEM ĐÃ CẮT CHƯA ---
    # Kiểm tra sự tồn tại của clip đầu tiên
    label_dir = os.path.join(CLIP_OUTPUT_PATH, label)
    first_clip_name = f"{video_name.split('.')[0]}_clip1.mp4"
    first_clip_path = os.path.join(label_dir, first_clip_name)
    
    if os.path.exists(first_clip_path):
        # Nếu file clip 1 đã tồn tại, ta giả định video này đã được xử lý
        total_videos_skipped += 1
        continue
    # -------------------------------------------

    # Nếu chưa tồn tại, tiến hành cắt
    print(f"Đang xử lý (cắt mới): '{video_name}'...")
    num_clips = trim_video_sliding_window(video_name, label)
    total_clips_generated_this_run += num_clips
    total_videos_processed += 1

print(f"\nHoàn thành!")
print(f"  Đã xử lý (cắt mới) trong lần chạy này: {total_videos_processed} video (tạo ra {total_clips_generated_this_run} clips).")
print(f"  Đã bỏ qua (vì đã có sẵn): {total_videos_skipped} video.")
# Out:
# Bắt đầu chuẩn bị dữ liệu Train (Sliding Window)...
# Tổng số video cần kiểm tra: 532
# Đang xử lý (cắt mới): 'Abuse013_x264.mp4'...
#   Đã cắt video 'Abuse013_x264.mp4' thành 79 clips.
# Đang xử lý (cắt mới): 'Abuse014_x264.mp4'...
#   Đã cắt video 'Abuse014_x264.mp4' thành 41 clips.
# Đang xử lý (cắt mới): 'Abuse015_x264.mp4'...
#   Đã cắt video 'Abuse015_x264.mp4' thành 129 clips.
# Đang xử lý (cắt mới): 'Abuse016_x264.mp4'...
#   Đã cắt video 'Abuse016_x264.mp4' thành 21 clips.
# Đang xử lý (cắt mới): 'Abuse017_x264.mp4'...
#   Đã cắt video 'Abuse017_x264.mp4' thành 30 clips.
# Đang xử lý (cắt mới): 'Abuse018_x264.mp4'...
#   Đã cắt video 'Abuse018_x264.mp4' thành 38 clips.
# Đang xử lý (cắt mới): 'Abuse019_x264.mp4'...
#   Đã cắt video 'Abuse019_x264.mp4' thành 64 clips.
# Đang xử lý (cắt mới): 'Abuse020_x264.mp4'...
#   Đã cắt video 'Abuse020_x264.mp4' thành 50 clips.
# Đang xử lý (cắt mới): 'Abuse021_x264.mp4'...
#   Đã cắt video 'Abuse021_x264.mp4' thành 30 clips.
# Đang xử lý (cắt mới): 'Abuse022_x264.mp4'...
#   Đã cắt video 'Abuse022_x264.mp4' thành 45 clips.
# Đang xử lý (cắt mới): 'Abuse023_x264.mp4'...
#   Đã cắt video 'Abuse023_x264.mp4' thành 15 clips.
# Đang xử lý (cắt mới): 'Abuse024_x264.mp4'...
#   Đã cắt video 'Abuse024_x264.mp4' thành 15 clips.
# Đang xử lý (cắt mới): 'Abuse025_x264.mp4'...
#   Đã cắt video 'Abuse025_x264.mp4' thành 32 clips.
# Đang xử lý (cắt mới): 'Abuse026_x264.mp4'...
#   Đã cắt video 'Abuse026_x264.mp4' thành 31 clips.
# Đang xử lý (cắt mới): 'Abuse027_x264.mp4'...
#   Đã cắt video 'Abuse027_x264.mp4' thành 71 clips.
# Đang xử lý (cắt mới): 'Abuse028_x264.mp4'...
#   Đã cắt video 'Abuse028_x264.mp4' thành 22 clips.
# Đang xử lý (cắt mới): 'Abuse029_x264.mp4'...
#   Đã cắt video 'Abuse029_x264.mp4' thành 3 clips.
# Đang xử lý (cắt mới): 'Abuse030_x264.mp4'...
#   Đã cắt video 'Abuse030_x264.mp4' thành 24 clips.
# Đang xử lý (cắt mới): 'Abuse031_x264.mp4'...
#   Đã cắt video 'Abuse031_x264.mp4' thành 72 clips.
# Đang xử lý (cắt mới): 'Abuse032_x264.mp4'...
#   Đã cắt video 'Abuse032_x264.mp4' thành 77 clips.
# Đang xử lý (cắt mới): 'Abuse033_x264.mp4'...
#   Đã cắt video 'Abuse033_x264.mp4' thành 45 clips.
# Đang xử lý (cắt mới): 'Abuse034_x264.mp4'...
#   Đã cắt video 'Abuse034_x264.mp4' thành 24 clips.
# Đang xử lý (cắt mới): 'Abuse035_x264.mp4'...
#   Đã cắt video 'Abuse035_x264.mp4' thành 42 clips.
# Đang xử lý (cắt mới): 'Abuse036_x264.mp4'...
#   Đã cắt video 'Abuse036_x264.mp4' thành 76 clips.
# Đang xử lý (cắt mới): 'Abuse037_x264.mp4'...
#   Đã cắt video 'Abuse037_x264.mp4' thành 28 clips.
# Đang xử lý (cắt mới): 'Abuse038_x264.mp4'...
#   Đã cắt video 'Abuse038_x264.mp4' thành 13 clips.
# Đang xử lý (cắt mới): 'Abuse039_x264.mp4'...
#   Đã cắt video 'Abuse039_x264.mp4' thành 234 clips.
# Đang xử lý (cắt mới): 'Abuse040_x264.mp4'...
#   Đã cắt video 'Abuse040_x264.mp4' thành 55 clips.
# Đang xử lý (cắt mới): 'Abuse041_x264.mp4'...
#   Đã cắt video 'Abuse041_x264.mp4' thành 21 clips.
# Đang xử lý (cắt mới): 'Abuse042_x264.mp4'...
#   Đã cắt video 'Abuse042_x264.mp4' thành 473 clips.
# Đang xử lý (cắt mới): 'Abuse043_x264.mp4'...
#   Đã cắt video 'Abuse043_x264.mp4' thành 63 clips.
# Đang xử lý (cắt mới): 'Abuse044_x264.mp4'...
#   Đã cắt video 'Abuse044_x264.mp4' thành 64 clips.
# Đang xử lý (cắt mới): 'Abuse045_x264.mp4'...
#   Đã cắt video 'Abuse045_x264.mp4' thành 83 clips.
# Đang xử lý (cắt mới): 'Abuse046_x264.mp4'...
#   Đã cắt video 'Abuse046_x264.mp4' thành 17 clips.
# Đang xử lý (cắt mới): 'Abuse047_x264.mp4'...
#   Đã cắt video 'Abuse047_x264.mp4' thành 24 clips.
# Đang xử lý (cắt mới): 'Abuse048_x264.mp4'...
#   Đã cắt video 'Abuse048_x264.mp4' thành 55 clips.
# Đang xử lý (cắt mới): 'Abuse049_x264.mp4'...
#   Đã cắt video 'Abuse049_x264.mp4' thành 34 clips.
# Đang xử lý (cắt mới): 'Abuse050_x264.mp4'...
#   Đã cắt video 'Abuse050_x264.mp4' thành 79 clips.
# Đang xử lý (cắt mới): 'Arrest013_x264.mp4'...
#   Đã cắt video 'Arrest013_x264.mp4' thành 17 clips.
# Đang xử lý (cắt mới): 'Arrest014_x264.mp4'...
#   Đã cắt video 'Arrest014_x264.mp4' thành 24 clips.
# Đang xử lý (cắt mới): 'Arrest015_x264.mp4'...
#   Đã cắt video 'Arrest015_x264.mp4' thành 14 clips.
# Đang xử lý (cắt mới): 'Arrest016_x264.mp4'...
#   Đã cắt video 'Arrest016_x264.mp4' thành 174 clips.
# Đang xử lý (cắt mới): 'Arrest017_x264.mp4'...
#   Đã cắt video 'Arrest017_x264.mp4' thành 55 clips.
# Đang xử lý (cắt mới): 'Arrest018_x264.mp4'...
#   Đã cắt video 'Arrest018_x264.mp4' thành 39 clips.
# Đang xử lý (cắt mới): 'Arrest019_x264.mp4'...
#   Đã cắt video 'Arrest019_x264.mp4' thành 21 clips.
# Đang xử lý (cắt mới): 'Arrest020_x264.mp4'...
#   Đã cắt video 'Arrest020_x264.mp4' thành 47 clips.
# Đang xử lý (cắt mới): 'Arrest021_x264.mp4'...
#   Đã cắt video 'Arrest021_x264.mp4' thành 144 clips.
# Đang xử lý (cắt mới): 'Arrest022_x264.mp4'...
#   Đã cắt video 'Arrest022_x264.mp4' thành 25 clips.
# Đang xử lý (cắt mới): 'Arrest023_x264.mp4'...
#   Đã cắt video 'Arrest023_x264.mp4' thành 28 clips.
# Đang xử lý (cắt mới): 'Arrest024_x264.mp4'...
#   Đã cắt video 'Arrest024_x264.mp4' thành 58 clips.
# Đang xử lý (cắt mới): 'Arrest025_x264.mp4'...
#   Đã cắt video 'Arrest025_x264.mp4' thành 16 clips.
# Đang xử lý (cắt mới): 'Arrest026_x264.mp4'...
#   Đã cắt video 'Arrest026_x264.mp4' thành 106 clips.
# Đang xử lý (cắt mới): 'Arrest027_x264.mp4'...
#   Đã cắt video 'Arrest027_x264.mp4' thành 26 clips.
# Đang xử lý (cắt mới): 'Arrest028_x264.mp4'...
#   Đã cắt video 'Arrest028_x264.mp4' thành 40 clips.
# Đang xử lý (cắt mới): 'Arrest029_x264.mp4'...
#   Đã cắt video 'Arrest029_x264.mp4' thành 127 clips.
# Đang xử lý (cắt mới): 'Arrest030_x264.mp4'...
#   Đã cắt video 'Arrest030_x264.mp4' thành 142 clips.
# Đang xử lý (cắt mới): 'Arrest031_x264.mp4'...
#   Đã cắt video 'Arrest031_x264.mp4' thành 29 clips.
# Đang xử lý (cắt mới): 'Arrest032_x264.mp4'...
#   Đã cắt video 'Arrest032_x264.mp4' thành 26 clips.
# Đang xử lý (cắt mới): 'Arrest033_x264.mp4'...
#   Đã cắt video 'Arrest033_x264.mp4' thành 127 clips.
# Đang xử lý (cắt mới): 'Arrest034_x264.mp4'...
#   Đã cắt video 'Arrest034_x264.mp4' thành 192 clips.
# Đang xử lý (cắt mới): 'Arrest035_x264.mp4'...
#   Đã cắt video 'Arrest035_x264.mp4' thành 101 clips.
# Đang xử lý (cắt mới): 'Arrest036_x264.mp4'...
#   Đã cắt video 'Arrest036_x264.mp4' thành 62 clips.
# Đang xử lý (cắt mới): 'Arrest037_x264.mp4'...
#   Đã cắt video 'Arrest037_x264.mp4' thành 34 clips.
# Đang xử lý (cắt mới): 'Arrest038_x264.mp4'...
#   Đã cắt video 'Arrest038_x264.mp4' thành 35 clips.
# Đang xử lý (cắt mới): 'Arrest039_x264.mp4'...
#   Đã cắt video 'Arrest039_x264.mp4' thành 262 clips.
# Đang xử lý (cắt mới): 'Arrest040_x264.mp4'...
#   Đã cắt video 'Arrest040_x264.mp4' thành 28 clips.
# Đang xử lý (cắt mới): 'Arrest041_x264.mp4'...
#   Đã cắt video 'Arrest041_x264.mp4' thành 62 clips.
# Đang xử lý (cắt mới): 'Arrest042_x264.mp4'...
#   Đã cắt video 'Arrest042_x264.mp4' thành 25 clips.
# Đang xử lý (cắt mới): 'Arrest043_x264.mp4'...
#   Đã cắt video 'Arrest043_x264.mp4' thành 178 clips.
# Đang xử lý (cắt mới): 'Arrest044_x264.mp4'...
#   Đã cắt video 'Arrest044_x264.mp4' thành 55 clips.
# Đang xử lý (cắt mới): 'Arrest046_x264.mp4'...
#   Đã cắt video 'Arrest046_x264.mp4' thành 129 clips.
# Đang xử lý (cắt mới): 'Arrest047_x264.mp4'...
#   Đã cắt video 'Arrest047_x264.mp4' thành 1049 clips.
# Đang xử lý (cắt mới): 'Assault038_x264.mp4'...
#   Đã cắt video 'Assault038_x264.mp4' thành 0 clips.
# Đang xử lý (cắt mới): 'Explosion047_x264.mp4'...
#   Đã cắt video 'Explosion047_x264.mp4' thành 21 clips.
# Đang xử lý (cắt mới): 'Explosion048_x264.mp4'...
#   Đã cắt video 'Explosion048_x264.mp4' thành 6 clips.
# Đang xử lý (cắt mới): 'Explosion050_x264.mp4'...
#   Đã cắt video 'Explosion050_x264.mp4' thành 3 clips.
# Đang xử lý (cắt mới): 'Explosion051_x264.mp4'...
#   Đã cắt video 'Explosion051_x264.mp4' thành 45 clips.
# Đang xử lý (cắt mới): 'Explosion052_x264.mp4'...
#   Đã cắt video 'Explosion052_x264.mp4' thành 59 clips.
# Đang xử lý (cắt mới): 'Fighting014_x264.mp4'...
#   Đã cắt video 'Fighting014_x264.mp4' thành 76 clips.
# Đang xử lý (cắt mới): 'Fighting015_x264.mp4'...
#   Đã cắt video 'Fighting015_x264.mp4' thành 163 clips.
# Đang xử lý (cắt mới): 'Fighting016_x264.mp4'...
#   Đã cắt video 'Fighting016_x264.mp4' thành 46 clips.
# Đang xử lý (cắt mới): 'Fighting017_x264.mp4'...
#   Đã cắt video 'Fighting017_x264.mp4' thành 33 clips.
# Đang xử lý (cắt mới): 'Fighting018_x264.mp4'...
#   Đã cắt video 'Fighting018_x264.mp4' thành 21 clips.
# Đang xử lý (cắt mới): 'Fighting019_x264.mp4'...
#   Đã cắt video 'Fighting019_x264.mp4' thành 52 clips.
# Đang xử lý (cắt mới): 'Fighting020_x264.mp4'...
#   Đã cắt video 'Fighting020_x264.mp4' thành 35 clips.
# Đang xử lý (cắt mới): 'Fighting021_x264.mp4'...
#   Đã cắt video 'Fighting021_x264.mp4' thành 57 clips.
# Đang xử lý (cắt mới): 'Fighting022_x264.mp4'...
#   Đã cắt video 'Fighting022_x264.mp4' thành 71 clips.
#   Đã cắt video 'RoadAccidents027_x264.mp4' thành 0 clips.
# Đang xử lý (cắt mới): 'RoadAccidents028_x264.mp4'...
#   Đã cắt video 'RoadAccidents028_x264.mp4' thành 8 clips.
# Đang xử lý (cắt mới): 'RoadAccidents029_x264.mp4'...
#   Đã cắt video 'RoadAccidents029_x264.mp4' thành 7 clips.
# Đang xử lý (cắt mới): 'RoadAccidents030_x264.mp4'...
#   Đã cắt video 'RoadAccidents030_x264.mp4' thành 20 clips.
# Đang xử lý (cắt mới): 'RoadAccidents031_x264.mp4'...
#   Đã cắt video 'RoadAccidents031_x264.mp4' thành 34 clips.
# Đang xử lý (cắt mới): 'RoadAccidents032_x264.mp4'...
#   Đã cắt video 'RoadAccidents032_x264.mp4' thành 36 clips.
# Đang xử lý (cắt mới): 'RoadAccidents033_x264.mp4'...
#   Đã cắt video 'RoadAccidents033_x264.mp4' thành 8 clips.
# Đang xử lý (cắt mới): 'RoadAccidents034_x264.mp4'...
#   Đã cắt video 'RoadAccidents034_x264.mp4' thành 27 clips.
# Đang xử lý (cắt mới): 'RoadAccidents035_x264.mp4'...
#   Đã cắt video 'RoadAccidents035_x264.mp4' thành 3 clips.
# Đang xử lý (cắt mới): 'RoadAccidents036_x264.mp4'...
#   Đã cắt video 'RoadAccidents036_x264.mp4' thành 20 clips.
# Đang xử lý (cắt mới): 'RoadAccidents037_x264.mp4'...
#   Đã cắt video 'RoadAccidents037_x264.mp4' thành 34 clips.
# Đang xử lý (cắt mới): 'RoadAccidents038_x264.mp4'...
#   Đã cắt video 'RoadAccidents038_x264.mp4' thành 6 clips.
# Đang xử lý (cắt mới): 'RoadAccidents039_x264.mp4'...
#   Đã cắt video 'RoadAccidents039_x264.mp4' thành 4 clips.
# Đang xử lý (cắt mới): 'RoadAccidents040_x264.mp4'...
#   Đã cắt video 'RoadAccidents040_x264.mp4' thành 30 clips.
# Đang xử lý (cắt mới): 'RoadAccidents041_x264.mp4'...
#   Đã cắt video 'RoadAccidents041_x264.mp4' thành 2 clips.
# Đang xử lý (cắt mới): 'RoadAccidents042_x264.mp4'...
#   Đã cắt video 'RoadAccidents042_x264.mp4' thành 13 clips.
# Đang xử lý (cắt mới): 'RoadAccidents043_x264.mp4'...
#   Đã cắt video 'RoadAccidents043_x264.mp4' thành 1 clips.
# Đang xử lý (cắt mới): 'RoadAccidents044_x264.mp4'...
#   Đã cắt video 'RoadAccidents044_x264.mp4' thành 5 clips.
# Đang xử lý (cắt mới): 'RoadAccidents046_x264.mp4'...
#   Đã cắt video 'RoadAccidents046_x264.mp4' thành 9 clips.
# Đang xử lý (cắt mới): 'RoadAccidents047_x264.mp4'...
#   Đã cắt video 'RoadAccidents047_x264.mp4' thành 5 clips.
# Đang xử lý (cắt mới): 'RoadAccidents048_x264.mp4'...
#   Đã cắt video 'RoadAccidents048_x264.mp4' thành 38 clips.
# Đang xử lý (cắt mới): 'RoadAccidents049_x264.mp4'...
#   Đã cắt video 'RoadAccidents049_x264.mp4' thành 10 clips.
# Đang xử lý (cắt mới): 'RoadAccidents050_x264.mp4'...
#   Đã cắt video 'RoadAccidents050_x264.mp4' thành 16 clips.
# Đang xử lý (cắt mới): 'RoadAccidents051_x264.mp4'...
#   Đã cắt video 'RoadAccidents051_x264.mp4' thành 5 clips.
# Đang xử lý (cắt mới): 'Robbery013_x264.mp4'...
#   Đã cắt video 'Robbery013_x264.mp4' thành 59 clips.
# Đang xử lý (cắt mới): 'Robbery014_x264.mp4'...
#   Đã cắt video 'Robbery014_x264.mp4' thành 253 clips.
# Đang xử lý (cắt mới): 'Robbery015_x264.mp4'...
#   Đã cắt video 'Robbery015_x264.mp4' thành 44 clips.
# Đang xử lý (cắt mới): 'Robbery016_x264.mp4'...
#   Đã cắt video 'Robbery016_x264.mp4' thành 26 clips.
# Đang xử lý (cắt mới): 'Robbery017_x264.mp4'...
#   Đã cắt video 'Robbery017_x264.mp4' thành 71 clips.
# Đang xử lý (cắt mới): 'Robbery018_x264.mp4'...
#   Đã cắt video 'Robbery018_x264.mp4' thành 46 clips.
# Đang xử lý (cắt mới): 'Robbery019_x264.mp4'...
#   Đã cắt video 'Robbery019_x264.mp4' thành 94 clips.
# Đang xử lý (cắt mới): 'Robbery020_x264.mp4'...
#   Đã cắt video 'Robbery020_x264.mp4' thành 71 clips.
# Đang xử lý (cắt mới): 'Robbery021_x264.mp4'...
#   Đã cắt video 'Robbery021_x264.mp4' thành 135 clips.
# Đang xử lý (cắt mới): 'Robbery022_x264.mp4'...
#   Đã cắt video 'Robbery022_x264.mp4' thành 57 clips.
# Đang xử lý (cắt mới): 'Robbery023_x264.mp4'...
#   Đã cắt video 'Robbery023_x264.mp4' thành 17 clips.
# Đang xử lý (cắt mới): 'Robbery024_x264.mp4'...
#   Đã cắt video 'Robbery024_x264.mp4' thành 38 clips.
# Đang xử lý (cắt mới): 'Robbery025_x264.mp4'...
#   Đã cắt video 'Robbery025_x264.mp4' thành 22 clips.
# Đang xử lý (cắt mới): 'Robbery026_x264.mp4'...
#   Đã cắt video 'Robbery026_x264.mp4' thành 217 clips.
# Đang xử lý (cắt mới): 'Robbery027_x264.mp4'...
#   Đã cắt video 'Robbery027_x264.mp4' thành 88 clips.
# Đang xử lý (cắt mới): 'Robbery028_x264.mp4'...
#   Đã cắt video 'Robbery028_x264.mp4' thành 37 clips.
# Đang xử lý (cắt mới): 'Robbery029_x264.mp4'...
#   Đã cắt video 'Robbery029_x264.mp4' thành 34 clips.
# Đang xử lý (cắt mới): 'Robbery030_x264.mp4'...
#   Đã cắt video 'Robbery030_x264.mp4' thành 48 clips.
# Đang xử lý (cắt mới): 'Robbery031_x264.mp4'...
#   Đã cắt video 'Robbery031_x264.mp4' thành 16 clips.
# Đang xử lý (cắt mới): 'Robbery032_x264.mp4'...
#   Đã cắt video 'Robbery032_x264.mp4' thành 88 clips.
# Đang xử lý (cắt mới): 'Robbery033_x264.mp4'...
#   Đã cắt video 'Robbery033_x264.mp4' thành 14 clips.
# Đang xử lý (cắt mới): 'Robbery034_x264.mp4'...
#   Đã cắt video 'Robbery034_x264.mp4' thành 104 clips.
# Đang xử lý (cắt mới): 'Robbery035_x264.mp4'...
#   Đã cắt video 'Robbery035_x264.mp4' thành 76 clips.
# Đang xử lý (cắt mới): 'Robbery036_x264.mp4'...
#   Đã cắt video 'Robbery036_x264.mp4' thành 101 clips.
# Đang xử lý (cắt mới): 'Robbery037_x264.mp4'...
#   Đã cắt video 'Robbery037_x264.mp4' thành 143 clips.
# Đang xử lý (cắt mới): 'Robbery038_x264.mp4'...
#   Đã cắt video 'Robbery038_x264.mp4' thành 29 clips.
# Đang xử lý (cắt mới): 'Robbery039_x264.mp4'...
#   Đã cắt video 'Robbery039_x264.mp4' thành 7 clips.
# Đang xử lý (cắt mới): 'Robbery040_x264.mp4'...
#   Đã cắt video 'Robbery040_x264.mp4' thành 15 clips.
# Đang xử lý (cắt mới): 'Robbery041_x264.mp4'...
#   Đã cắt video 'Robbery041_x264.mp4' thành 21 clips.
# Đang xử lý (cắt mới): 'Robbery042_x264.mp4'...
#   Đã cắt video 'Robbery042_x264.mp4' thành 34 clips.
# Đang xử lý (cắt mới): 'Robbery043_x264.mp4'...
#   Đã cắt video 'Robbery043_x264.mp4' thành 15 clips.
# Đang xử lý (cắt mới): 'Robbery044_x264.mp4'...
#   Đã cắt video 'Robbery044_x264.mp4' thành 6 clips.
# Đang xử lý (cắt mới): 'Robbery045_x264.mp4'...
#   Đã cắt video 'Robbery045_x264.mp4' thành 54 clips.
# Đang xử lý (cắt mới): 'Robbery046_x264.mp4'...
#   Đã cắt video 'Robbery046_x264.mp4' thành 12 clips.
# Đang xử lý (cắt mới): 'Robbery047_x264.mp4'...
#   Đã cắt video 'Robbery047_x264.mp4' thành 23 clips.
# Đang xử lý (cắt mới): 'Robbery048_x264.mp4'...
#   Đã cắt video 'Robbery048_x264.mp4' thành 21 clips.
# Đang xử lý (cắt mới): 'Robbery049_x264.mp4'...
#   Đã cắt video 'Robbery049_x264.mp4' thành 31 clips.
# Đang xử lý (cắt mới): 'Robbery050_x264.mp4'...
#   Đã cắt video 'Robbery050_x264.mp4' thành 26 clips.
# Đang xử lý (cắt mới): 'Shooting013_x264.mp4'...
#   Đã cắt video 'Shooting013_x264.mp4' thành 16 clips.
# Đang xử lý (cắt mới): 'Shooting014_x264.mp4'...
#   Đã cắt video 'Shooting014_x264.mp4' thành 105 clips.
# Đang xử lý (cắt mới): 'Shooting015_x264.mp4'...
#   Đã cắt video 'Shooting015_x264.mp4' thành 27 clips.
# Đang xử lý (cắt mới): 'Shooting017_x264.mp4'...
#   Đã cắt video 'Shooting017_x264.mp4' thành 14 clips.
# Đang xử lý (cắt mới): 'Shooting018_x264.mp4'...
#   Đã cắt video 'Shooting018_x264.mp4' thành 28 clips.
# Đang xử lý (cắt mới): 'Shooting019_x264.mp4'...
#   Đã cắt video 'Shooting019_x264.mp4' thành 44 clips.
# Đang xử lý (cắt mới): 'Shooting020_x264.mp4'...
#   Đã cắt video 'Shooting020_x264.mp4' thành 83 clips.
# Đang xử lý (cắt mới): 'Shooting021_x264.mp4'...
#   Đã cắt video 'Shooting021_x264.mp4' thành 19 clips.
# Đang xử lý (cắt mới): 'Shooting022_x264.mp4'...
#   Đã cắt video 'Shooting022_x264.mp4' thành 74 clips.
x264.mp4' thành 21 clips.
# Đang xử lý (cắt mới): 'Shooting052_x264.mp4'...
#   Đã cắt video 'Shooting052_x264.mp4' thành 91 clips.
# Đang xử lý (cắt mới): 'Shooting053_x264.mp4'...
#   Đã cắt video 'Shooting053_x264.mp4' thành 13 clips.
# Đang xử lý (cắt mới): 'Shooting054_x264.mp4'...
#   Đã cắt video 'Shooting054_x264.mp4' thành 10 clips.
# Đang xử lý (cắt mới): 'Shoplifting015_x264.mp4'...
#   Đã cắt video 'Shoplifting015_x264.mp4' thành 36 clips.
# Đang xử lý (cắt mới): 'Shoplifting016_x264.mp4'...
#   Đã cắt video 'Shoplifting016_x264.mp4' thành 23 clips.
# Đang xử lý (cắt mới): 'Shoplifting017_x264.mp4'...
#   Đã cắt video 'Shoplifting017_x264.mp4' thành 6 clips.
# Đang xử lý (cắt mới): 'Shoplifting018_x264.mp4'...
#   Đã cắt video 'Shoplifting018_x264.mp4' thành 34 clips.
# Đang xử lý (cắt mới): 'Shoplifting019_x264.mp4'...
#   Đã cắt video 'Shoplifting019_x264.mp4' thành 9 clips.
# Đang xử lý (cắt mới): 'Shoplifting020_x264.mp4'...
#   Đã cắt video 'Shoplifting020_x264.mp4' thành 94 clips.
# Đang xử lý (cắt mới): 'Shoplifting021_x264.mp4'...
#   Đã cắt video 'Shoplifting021_x264.mp4' thành 57 clips.
# Đang xử lý (cắt mới): 'Shoplifting022_x264.mp4'...
#   Đã cắt video 'Shoplifting022_x264.mp4' thành 35 clips.
# Đang xử lý (cắt mới): 'Shoplifting024_x264.mp4'...
#   Đã cắt video 'Shoplifting024_x264.mp4' thành 18 clips.
# Đang xử lý (cắt mới): 'Shoplifting025_x264.mp4'...
#   Đã cắt video 'Shoplifting025_x264.mp4' thành 28 clips.
# Đang xử lý (cắt mới): 'Shoplifting026_x264.mp4'...
#   Đã cắt video 'Shoplifting026_x264.mp4' thành 22 clips.
# Đang xử lý (cắt mới): 'Shoplifting027_x264.mp4'...
#   Đã cắt video 'Shoplifting027_x264.mp4' thành 29 clips.
# Đang xử lý (cắt mới): 'Shoplifting028_x264.mp4'...
#   Đã cắt video 'Shoplifting028_x264.mp4' thành 21 clips.
# Đang xử lý (cắt mới): 'Shoplifting029_x264.mp4'...
#   Đã cắt video 'Shoplifting029_x264.mp4' thành 34 clips.
# Đang xử lý (cắt mới): 'Shoplifting030_x264.mp4'...
#   Đã cắt video 'Shoplifting030_x264.mp4' thành 401 clips.
# Đang xử lý (cắt mới): 'Shoplifting031_x264.mp4'...
#   Đã cắt video 'Shoplifting031_x264.mp4' thành 5 clips.
# Đang xử lý (cắt mới): 'Shoplifting032_x264.mp4'...
#   Đã cắt video 'Shoplifting032_x264.mp4' thành 22 clips.
# Đang xử lý (cắt mới): 'Shoplifting033_x264.mp4'...
#   Đã cắt video 'Shoplifting033_x264.mp4' thành 13 clips.
# Đang xử lý (cắt mới): 'Shoplifting034_x264.mp4'...
#   Đã cắt video 'Shoplifting034_x264.mp4' thành 197 clips.
# Đang xử lý (cắt mới): 'Shoplifting036_x264.mp4'...
#   Đã cắt video 'Shoplifting036_x264.mp4' thành 59 clips.
# Đang xử lý (cắt mới): 'Shoplifting037_x264.mp4'...
#   Đã cắt video 'Shoplifting037_x264.mp4' thành 21 clips.
# Đang xử lý (cắt mới): 'Shoplifting038_x264.mp4'...
#   Đã cắt video 'Shoplifting038_x264.mp4' thành 46 clips.
# Đang xử lý (cắt mới): 'Shoplifting039_x264.mp4'...
#   Đã cắt video 'Shoplifting039_x264.mp4' thành 45 clips.
# Đang xử lý (cắt mới): 'Shoplifting040_x264.mp4'...
#   Đã cắt video 'Shoplifting040_x264.mp4' thành 451 clips.
# Đang xử lý (cắt mới): 'Shoplifting041_x264.mp4'...
#   Đã cắt video 'Shoplifting041_x264.mp4' thành 204 clips.
# Đang xử lý (cắt mới): 'Shoplifting042_x264.mp4'...
#   Đã cắt video 'Shoplifting042_x264.mp4' thành 83 clips.
# Đang xử lý (cắt mới): 'Shoplifting043_x264.mp4'...
#   Đã cắt video 'Shoplifting043_x264.mp4' thành 157 clips.
# Đang xử lý (cắt mới): 'Shoplifting044_x264.mp4'...
#   Đã cắt video 'Shoplifting044_x264.mp4' thành 241 clips.
# Đang xử lý (cắt mới): 'Shoplifting045_x264.mp4'...
#   Đã cắt video 'Shoplifting045_x264.mp4' thành 25 clips.
# Đang xử lý (cắt mới): 'Shoplifting047_x264.mp4'...
#   Đã cắt video 'Shoplifting047_x264.mp4' thành 38 clips.
# Đang xử lý (cắt mới): 'Shoplifting048_x264.mp4'...
#   Đã cắt video 'Shoplifting048_x264.mp4' thành 50 clips.
# Đang xử lý (cắt mới): 'Shoplifting049_x264.mp4'...
#   Đã cắt video 'Shoplifting049_x264.mp4' thành 34 clips.
# Đang xử lý (cắt mới): 'Shoplifting050_x264.mp4'...
#   Đã cắt video 'Shoplifting050_x264.mp4' thành 40 clips.
# Đang xử lý (cắt mới): 'Shoplifting051_x264.mp4'...
#   Đã cắt video 'Shoplifting051_x264.mp4' thành 118 clips.
# Đang xử lý (cắt mới): 'Shoplifting052_x264.mp4'...
#   Đã cắt video 'Shoplifting052_x264.mp4' thành 125 clips.
# Đang xử lý (cắt mới): 'Shoplifting053_x264.mp4'...
#   Đã cắt video 'Shoplifting053_x264.mp4' thành 33 clips.
# Đang xử lý (cắt mới): 'Shoplifting054_x264.mp4'...
#   Đã cắt video 'Shoplifting054_x264.mp4' thành 15 clips.
# Đang xử lý (cắt mới): 'Shoplifting055_x264.mp4'...
#   Đã cắt video 'Shoplifting055_x264.mp4' thành 111 clips.
# Đang xử lý (cắt mới): 'Stealing015_x264.mp4'...
#   Đã cắt video 'Stealing015_x264.mp4' thành 28 clips.
# Đang xử lý (cắt mới): 'Stealing016_x264.mp4'...
#   Đã cắt video 'Stealing016_x264.mp4' thành 39 clips.
# Đang xử lý (cắt mới): 'Stealing017_x264.mp4'...
#   Đã cắt video 'Stealing017_x264.mp4' thành 29 clips.
# Đang xử lý (cắt mới): 'Stealing018_x264.mp4'...
#   Đã cắt video 'Stealing018_x264.mp4' thành 32 clips.
# Đang xử lý (cắt mới): 'Stealing019_x264.mp4'...
#   Đã cắt video 'Stealing019_x264.mp4' thành 80 clips.
# Đang xử lý (cắt mới): 'Stealing020_x264.mp4'...
#   Đã cắt video 'Stealing020_x264.mp4' thành 108 clips.
# Đang xử lý (cắt mới): 'Stealing021_x264.mp4'...
#   Đã cắt video 'Stealing021_x264.mp4' thành 67 clips.
# Đang xử lý (cắt mới): 'Stealing022_x264.mp4'...
#   Đã cắt video 'Stealing022_x264.mp4' thành 39 clips.
# Đang xử lý (cắt mới): 'Stealing023_x264.mp4'...
#   Đã cắt video 'Stealing023_x264.mp4' thành 83 clips.
# Đang xử lý (cắt mới): 'Stealing024_x264.mp4'...
#   Đã cắt video 'Stealing024_x264.mp4' thành 39 clips.
# Đang xử lý (cắt mới): 'Stealing025_x264.mp4'...
#   Đã cắt video 'Stealing025_x264.mp4' thành 362 clips.
# Đang xử lý (cắt mới): 'Stealing026_x264.mp4'...
#   Đã cắt video 'Stealing026_x264.mp4' thành 44 clips.
# Đang xử lý (cắt mới): 'Stealing027_x264.mp4'...
#   Đã cắt video 'Stealing027_x264.mp4' thành 30 clips.
# Đang xử lý (cắt mới): 'Stealing028_x264.mp4'...
#   Đã cắt video 'Stealing028_x264.mp4' thành 27 clips.
# Đang xử lý (cắt mới): 'Stealing029_x264.mp4'...
#   Đã cắt video 'Stealing029_x264.mp4' thành 5 clips.
# Đang xử lý (cắt mới): 'Stealing030_x264.mp4'...
#   Đã cắt video 'Stealing030_x264.mp4' thành 12 clips.
# Đang xử lý (cắt mới): 'Stealing031_x264.mp4'...
#   Đã cắt video 'Stealing031_x264.mp4' thành 16 clips.
# Đang xử lý (cắt mới): 'Stealing032_x264.mp4'...
#   Đã cắt video 'Stealing032_x264.mp4' thành 88 clips.
# Đang xử lý (cắt mới): 'Stealing035_x264.mp4'...
#   Đã cắt video 'Stealing035_x264.mp4' thành 184 clips.
# Đang xử lý (cắt mới): 'Stealing036_x264.mp4'...
#   Đã cắt video 'Stealing036_x264.mp4' thành 40 clips.
# Đang xử lý (cắt mới): 'Stealing037_x264.mp4'...
#   Đã cắt video 'Stealing037_x264.mp4' thành 77 clips.
# Đang xử lý (cắt mới): 'Stealing042_x264.mp4'...
#   Đã cắt video 'Stealing042_x264.mp4' thành 68 clips.
# Đang xử lý (cắt mới): 'Stealing043_x264.mp4'...
#   Đã cắt video 'Stealing043_x264.mp4' thành 78 clips.
# Đang xử lý (cắt mới): 'Stealing044_x264.mp4'...
#   Đã cắt video 'Stealing044_x264.mp4' thành 52 clips.
# Đang xử lý (cắt mới): 'Stealing045_x264.mp4'...
#   Đã cắt video 'Stealing045_x264.mp4' thành 176 clips.
# Đang xử lý (cắt mới): 'Stealing046_x264.mp4'...
#   Đã cắt video 'Stealing046_x264.mp4' thành 170 clips.
# Đang xử lý (cắt mới): 'Stealing047_x264.mp4'...
#   Đã cắt video 'Stealing047_x264.mp4' thành 21 clips.
# Đang xử lý (cắt mới): 'Stealing048_x264.mp4'...
#   Đã cắt video 'Stealing048_x264.mp4' thành 124 clips.
# Đang xử lý (cắt mới): 'Stealing049_x264.mp4'...
#   Đã cắt video 'Stealing049_x264.mp4' thành 23 clips.
# Đang xử lý (cắt mới): 'Stealing050_x264.mp4'...
#   Đã cắt video 'Stealing050_x264.mp4' thành 54 clips.
# Đang xử lý (cắt mới): 'Stealing051_x264.mp4'...
#   Đã cắt video 'Stealing051_x264.mp4' thành 54 clips.
# Đang xử lý (cắt mới): 'Stealing052_x264.mp4'...
#   Đã cắt video 'Stealing052_x264.mp4' thành 54 clips.
# Đang xử lý (cắt mới): 'Stealing053_x264.mp4'...
#   Đã cắt video 'Stealing053_x264.mp4' thành 216 clips.
# Đang xử lý (cắt mới): 'Stealing054_x264.mp4'...
#   Đã cắt video 'Stealing054_x264.mp4' thành 42 clips.
# Đang xử lý (cắt mới): 'Stealing055_x264.mp4'...
#   Đã cắt video 'Stealing055_x264.mp4' thành 25 clips.
# Đang xử lý (cắt mới): 'Stealing057_x264.mp4'...
#   Đã cắt video 'Stealing057_x264.mp4' thành 48 clips.
# Đang xử lý (cắt mới): 'Stealing058_x264.mp4'...
#   Đã cắt video 'Stealing058_x264.mp4' thành 81 clips.
# Đang xử lý (cắt mới): 'Stealing059_x264.mp4'...
#   Đã cắt video 'Stealing059_x264.mp4' thành 35 clips.
# Đang xử lý (cắt mới): 'Vandalism013_x264.mp4'...
#   Đã cắt video 'Vandalism013_x264.mp4' thành 38 clips.
# Đang xử lý (cắt mới): 'Vandalism014_x264.mp4'...
#   Đã cắt video 'Vandalism014_x264.mp4' thành 5 clips.
# Đang xử lý (cắt mới): 'Vandalism015_x264.mp4'...
#   Đã cắt video 'Vandalism015_x264.mp4' thành 48 clips.
# Đang xử lý (cắt mới): 'Vandalism016_x264.mp4'...
#   Đã cắt video 'Vandalism016_x264.mp4' thành 95 clips.
# Đang xử lý (cắt mới): 'Vandalism017_x264.mp4'...
#   Đã cắt video 'Vandalism017_x264.mp4' thành 15 clips.
# Đang xử lý (cắt mới): 'Vandalism018_x264.mp4'...
#   Đã cắt video 'Vandalism018_x264.mp4' thành 91 clips.
# Đang xử lý (cắt mới): 'Vandalism019_x264.mp4'...
#   Đã cắt video 'Vandalism019_x264.mp4' thành 32 clips.
# Đang xử lý (cắt mới): 'Vandalism020_x264.mp4'...
#   Đã cắt video 'Vandalism020_x264.mp4' thành 22 clips.
# Đang xử lý (cắt mới): 'Vandalism021_x264.mp4'...
#   Đã cắt video 'Vandalism021_x264.mp4' thành 21 clips.
# Đang xử lý (cắt mới): 'Vandalism022_x264.mp4'...
#   Đã cắt video 'Vandalism022_x264.mp4' thành 64 clips.
# Đang xử lý (cắt mới): 'Vandalism023_x264.mp4'...
#   Đã cắt video 'Vandalism023_x264.mp4' thành 103 clips.
# Đang xử lý (cắt mới): 'Vandalism024_x264.mp4'...
#   Đã cắt video 'Vandalism024_x264.mp4' thành 15 clips.
# Đang xử lý (cắt mới): 'Vandalism025_x264.mp4'...
#   Đã cắt video 'Vandalism025_x264.mp4' thành 70 clips.
# Đang xử lý (cắt mới): 'Vandalism026_x264.mp4'...
#   Đã cắt video 'Vandalism026_x264.mp4' thành 14 clips.
# Đang xử lý (cắt mới): 'Vandalism027_x264.mp4'...
#   Đã cắt video 'Vandalism027_x264.mp4' thành 10 clips.
# Đang xử lý (cắt mới): 'Vandalism028_x264.mp4'...
#   Đã cắt video 'Vandalism028_x264.mp4' thành 73 clips.
# Đang xử lý (cắt mới): 'Vandalism029_x264.mp4'...
#   Đã cắt video 'Vandalism029_x264.mp4' thành 6 clips.
# Đang xử lý (cắt mới): 'Vandalism030_x264.mp4'...
#   Đã cắt video 'Vandalism030_x264.mp4' thành 22 clips.
# Đang xử lý (cắt mới): 'Vandalism031_x264.mp4'...
#   Đã cắt video 'Vandalism031_x264.mp4' thành 28 clips.
# Đang xử lý (cắt mới): 'Vandalism032_x264.mp4'...
#   Đã cắt video 'Vandalism032_x264.mp4' thành 9 clips.
# Đang xử lý (cắt mới): 'Vandalism033_x264.mp4'...
#   Đã cắt video 'Vandalism033_x264.mp4' thành 36 clips.
# Đang xử lý (cắt mới): 'Vandalism034_x264.mp4'...
#   Đã cắt video 'Vandalism034_x264.mp4' thành 27 clips.
# Đang xử lý (cắt mới): 'Vandalism035_x264.mp4'...
#   Đã cắt video 'Vandalism035_x264.mp4' thành 18 clips.
# Đang xử lý (cắt mới): 'Vandalism036_x264.mp4'...
#   Đã cắt video 'Vandalism036_x264.mp4' thành 22 clips.
# Đang xử lý (cắt mới): 'Vandalism037_x264.mp4'...
#   Đã cắt video 'Vandalism037_x264.mp4' thành 48 clips.
# Đang xử lý (cắt mới): 'Vandalism038_x264.mp4'...
#   Đã cắt video 'Vandalism038_x264.mp4' thành 45 clips.
# Đang xử lý (cắt mới): 'Vandalism039_x264.mp4'...
#   Đã cắt video 'Vandalism039_x264.mp4' thành 13 clips.
# Đang xử lý (cắt mới): 'Vandalism040_x264.mp4'...
#   Đã cắt video 'Vandalism040_x264.mp4' thành 15 clips.
# Đang xử lý (cắt mới): 'Vandalism041_x264.mp4'...
#   Đã cắt video 'Vandalism041_x264.mp4' thành 79 clips.
# Đang xử lý (cắt mới): 'Vandalism042_x264.mp4'...
#   Đã cắt video 'Vandalism042_x264.mp4' thành 58 clips.
# Đang xử lý (cắt mới): 'Vandalism043_x264.mp4'...
#   Đã cắt video 'Vandalism043_x264.mp4' thành 52 clips.
# Đang xử lý (cắt mới): 'Vandalism044_x264.mp4'...
#   Đã cắt video 'Vandalism044_x264.mp4' thành 75 clips.
# Đang xử lý (cắt mới): 'Vandalism045_x264.mp4'...
#   Đã cắt video 'Vandalism045_x264.mp4' thành 71 clips.
# Đang xử lý (cắt mới): 'Vandalism046_x264.mp4'...
#   Đã cắt video 'Vandalism046_x264.mp4' thành 33 clips.
# Đang xử lý (cắt mới): 'Vandalism047_x264.mp4'...
#   Đã cắt video 'Vandalism047_x264.mp4' thành 39 clips.
# Đang xử lý (cắt mới): 'Vandalism048_x264.mp4'...
#   Đã cắt video 'Vandalism048_x264.mp4' thành 118 clips.
# Đang xử lý (cắt mới): 'Vandalism049_x264.mp4'...
#   Đã cắt video 'Vandalism049_x264.mp4' thành 131 clips.
# Đang xử lý (cắt mới): 'Vandalism050_x264.mp4'...
#   Đã cắt video 'Vandalism050_x264.mp4' thành 13 clips.
#
# Hoàn thành!
#   Đã xử lý (cắt mới) trong lần chạy này: 382 video (tạo ra 23277 clips).
#   Đã bỏ qua (vì đã có sẵn): 150 video.
